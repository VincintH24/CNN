# %%
import pandas as pd
import plotly.express as px
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pylab import *
import seaborn as sns
# %matplotlib inline
import  statsmodels.api as sm
import statsmodels.stats.api as sms
from scipy.stats import boxcox
import warnings
warnings.filterwarnings('ignore')

# %%
Covid = pd.read_csv(r"C:\Users\Vinnie\OneDrive\Desktop\Covid_Final.csv")

# %%
Covid.T
# Out:
#                                                          0    \
# Country_Covid                                           Peru
# ConfirmedCases                                     3,588,697
# Deaths                                               213,308
# CaseFatality                                           5.90%
# Deaths_Per_100k                                       646.94
# Country_Vaccine                                  Afghanistan
# Doses administered per 100 people                       16.0
# Total doses administered                           6066579.0
# Pct_Population_Vaccination                              14.0
# Pct_Population_Fully_Vaccination                        12.0
# Dcovid_Related_Diseases              Ischemic heart diseases
# Covid19_Number                                         59.99
# Covid19_Percent                                        17.86
# Pneumonia_Influenza2019_Number                         65.24
# ...

# %%
fig = px.bar(Covid, x="Country_Covid", y="ConfirmedCases", color="Deaths", title="Country and conmfirmed cases by death")
(figsize:=(12,6))
fig.show()

# %%
fig = px.scatter(Covid, x="Dcovid_Related_Diseases", y="ConfirmedCases", color="Deaths", title="Disease type and conmfirmed cases by death")
(figsize:=(12,6))
fig.show()

# %%
fig = px.scatter(Covid, x="Date", y="Pct_Unvaccinated_Hospitalized", color="Pct_Unvaccinated_ICU", title="Disease type and conmfirmed cases by death")
(figsize:=(12,6))
fig.show()

# %%
fig = px.scatter(Covid, x='Date', y='Pct_Unvaccinated_Hospitalized')
fig.show()
fig = px.scatter(Covid, x='Date', y='Pct_3_Or_More_Doses_Hospitalized')
fig.show()
fig = px.scatter(Covid, x='Date', y='Pct_Vaccinated_2_Doses_Hospitalized')
fig.show()
fig = px.scatter(Covid, x='Date', y='Pct_Unvaccinated_ICU')
fig.show()
fig = px.scatter(Covid, x='Date', y='Pct_3_Or_More_Doses_ICU')
fig.show()
fig = px.scatter(Covid, x='Date', y='Pct_Vaccinated_2_Doses_ICU')
fig.show()
fig = px.scatter(Covid,'Pneumonia_Influenza2019_Number')
fig.show()
fig = px.scatter(Covid, 'Pneumonia_Influenza2020_Number')
fig.show()

# %%
fig = px.scatter(Covid, x="Doses administered per 100 people", y="ConfirmedCases", color="Deaths", title="Doses administered and conmfirmed cases by death")
(figsize:=(12,6))
fig.show()

# %%
Covid.sort_values(by=['Doses administered per 100 people', 'Deaths', 'ConfirmedCases'], inplace=True, ascending=False)

# %%
fig = px.scatter(Covid, x="Doses administered per 100 people", y="ConfirmedCases", color="Deaths", title="Doses administered and conmfirmed cases by death in descending order")
(figsize:=(12,6))
fig.show()

# %%
Covid.sort_values(by=['Doses administered per 100 people', 'Deaths', 'ConfirmedCases'], inplace=True, ascending=False)

# %%
fig = px.scatter(Covid, x='Doses administered per 100 people', y='ConfirmedCases')
fig.show()

# %%
fig = px.scatter(Covid["Pneumonia_Influenza2019_Number"])
fig.show()
fig = px.scatter(Covid["Pneumonia_Influenza2020_Number"])
fig.show()

# %%
fig = px.scatter(Covid, x='Dcovid_Related_Diseases', y='Covid19_Number')
fig.show()

# %%
fig = px.scatter(Covid, x='Doses administered per 100 people', y='CaseFatality')
fig.show()
